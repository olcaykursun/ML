# %% [markdown]
# <a href="https://colab.research.google.com/github/olcaykursun/ML/blob/main/neuralnets/conv_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, ReLU
import tensorflow as tf
import numpy as np

#model = Sequential([
#    Input(shape=(3, 3, 1)),
#    Conv2D(1, kernel_size=(2, 2), activation='relu'),
#    Flatten(),
#    Dense(1, activation='sigmoid')
#])


# Input layer
input_layer = Input(shape=(3, 3, 1))

# Convolutional layer
custom_kernel_initializer = tf.constant_initializer(-0.5)
custom_bias_initializer = tf.constant_initializer(1.5)
conv_layer = Conv2D(1, kernel_size=(2, 2), strides=(1, 1),
                    kernel_initializer=custom_kernel_initializer,
                    bias_initializer=custom_bias_initializer)(input_layer)
conv_activation = ReLU()(conv_layer)

# Flatten layer
flatten_layer = Flatten()(conv_activation)

# Dense (fully connected) layer
dense_layer = Dense(1, activation='sigmoid',
                    #kernel_initializer='ones',
                    #bias_initializer='zeros'
                   )(flatten_layer)

model = Model(inputs=input_layer, outputs=dense_layer)

# Define a new model that outputs activations from each layer
activation_model = Model(inputs=input_layer, outputs=[conv_layer, conv_activation, flatten_layer, dense_layer])

# Input image
input_image = np.array([[[1], [1], [1]],
                        [[1], [1], [1]],
                        [[0], [0], [0]]],

                       #add more images like the 3x3 image above

                       ).reshape(1, 3, 3, 1)

# Get activations
activations = activation_model.predict(input_image)

# Print the activations for each layer
for i, activation in enumerate(activations):
    print(f"Activation Layer {i}: \n{activation}\n")

# Compile the original model
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(input_image, np.array([0]), epochs=100, verbose=1)

# Get updated output (activation of the top layer)
activation_model = Model(inputs=input_layer, outputs=[conv_layer, conv_activation, flatten_layer, dense_layer])
activations = activation_model.predict(input_image)
print(f"{activations[-1]=}")
# Out:
# 1/1 [==============================] - 1s 537ms/step
# Activation Layer 0:
# [[[[-0.5]
#    [-0.5]]
#
#   [[ 0.5]
#    [ 0.5]]]]
#
# Activation Layer 1:
# [[[[0. ]
#    [0. ]]
#
#   [[0.5]
#    [0.5]]]]
#
# Activation Layer 2:
# [[0.  0.  0.5 0.5]]
#
# Activation Layer 3:
# [[0.58817184]]
#
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.8871 - accuracy: 0.0000e+00
# Epoch 2/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8768 - accuracy: 0.0000e+00
# Epoch 3/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8667 - accuracy: 0.0000e+00
# Epoch 4/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8569 - accuracy: 0.0000e+00
# Epoch 5/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8475 - accuracy: 0.0000e+00
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8383 - accuracy: 0.0000e+00
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8293 - accuracy: 0.0000e+00
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8207 - accuracy: 0.0000e+00
# Epoch 9/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8122 - accuracy: 0.0000e+00
# Epoch 10/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.8040 - accuracy: 0.0000e+00
# Epoch 11/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7960 - accuracy: 0.0000e+00
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7882 - accuracy: 0.0000e+00
# Epoch 13/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7806 - accuracy: 0.0000e+00
# Epoch 14/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7731 - accuracy: 0.0000e+00
# Epoch 15/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7659 - accuracy: 0.0000e+00
# Epoch 16/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7588 - accuracy: 0.0000e+00
# Epoch 17/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7519 - accuracy: 0.0000e+00
# Epoch 18/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7452 - accuracy: 0.0000e+00
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7386 - accuracy: 0.0000e+00
# Epoch 20/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7321 - accuracy: 0.0000e+00
# Epoch 21/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7258 - accuracy: 0.0000e+00
# Epoch 22/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7197 - accuracy: 0.0000e+00
# Epoch 23/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7136 - accuracy: 0.0000e+00
# Epoch 24/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7077 - accuracy: 0.0000e+00
# Epoch 25/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7019 - accuracy: 0.0000e+00
# Epoch 26/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6962 - accuracy: 0.0000e+00
# Epoch 27/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6906 - accuracy: 1.0000
# Epoch 28/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6851 - accuracy: 1.0000
# Epoch 29/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6797 - accuracy: 1.0000
# Epoch 30/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6744 - accuracy: 1.0000
# Epoch 31/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6692 - accuracy: 1.0000
# Epoch 32/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6641 - accuracy: 1.0000
# Epoch 33/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6591 - accuracy: 1.0000
# Epoch 34/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6541 - accuracy: 1.0000
# Epoch 35/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6492 - accuracy: 1.0000
# Epoch 36/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6444 - accuracy: 1.0000
# Epoch 37/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6397 - accuracy: 1.0000
# Epoch 38/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6351 - accuracy: 1.0000
# Epoch 39/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6305 - accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6260 - accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6215 - accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6171 - accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6128 - accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6085 - accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6043 - accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6001 - accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5960 - accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5919 - accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5879 - accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5839 - accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5799 - accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5760 - accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5722 - accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5687 - accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5668 - accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5649 - accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5631 - accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5612 - accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5594 - accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5575 - accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5557 - accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5539 - accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5521 - accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5503 - accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5485 - accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5467 - accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5450 - accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5432 - accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5414 - accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5397 - accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5379 - accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5362 - accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5345 - accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5328 - accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5311 - accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5294 - accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5277 - accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5260 - accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5244 - accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5227 - accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5210 - accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5194 - accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5177 - accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5161 - accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5145 - accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5129 - accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5113 - accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5097 - accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5081 - accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5065 - accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5049 - accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5033 - accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5018 - accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5002 - accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4987 - accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4971 - accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4956 - accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4941 - accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4926 - accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4911 - accuracy: 1.0000
# 1/1 [==============================] - 0s 196ms/step
# activations[-1]=array([[0.3870962]], dtype=float32)

# %%
model.fit(input_image, np.array([0]), epochs=100, verbose=0)
activation_model = Model(inputs=input_layer, outputs=[conv_layer, conv_activation, flatten_layer, dense_layer])
activations = activation_model.predict(input_image)
print(f"{activations[-1]=}")
# Out:
# 1/1 [==============================] - 0s 57ms/step
# activations[-1]=array([[0.30880493]], dtype=float32)

# %%
conv_layer_weights = model.layers[1].get_weights()

filter_weights = conv_layer_weights[0]  # This is a 4D tensor for Conv2D weights: (filter_height, filter_width, input_channels, output_channels)

first_filter_weights = filter_weights[:, :, 0, 0]  # For the first filter
print("First filter weights:\n", first_filter_weights)
# Out:
# First filter weights:
#  [[-0.6670722 -0.6670722]
#  [-0.5       -0.5      ]]
